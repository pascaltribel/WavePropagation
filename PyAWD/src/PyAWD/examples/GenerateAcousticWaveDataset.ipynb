# %%
import numpy as np
import devito as dvt
import matplotlib.pyplot as plt
import torch
from tqdm.notebook import tqdm

from PyAWD.GenerateVideo import *
from PyAWD.utils import *
from PyAWD.Marmousi import *
from PyAWD.AcousticWaveDataset import *

GENERATING = True

# %%
size = 100
nx = 128
ddt = 0.01
dt = 2
t = 10
batch_size = 10

if GENERATING:
    dataset = AcousticWaveDataset(size=size, nx=nx, ddt=ddt, dt=dt, t=t)
    torch.save(dataset, '../local/dev.pt')
else:
    dataset = torch.load('../local/dev.pt')
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
dataset.plot_item(3)

# %%
dataset.generate_video(3, "dataset_test", 240)
# Out:
# Generating 250 images.
#   0%|          | 0/250 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/ImageFile.py:515, in _save(im, fp, tile, bufsize)
#     514 try:
# --> 515     fh = fp.fileno()
#     516     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 dataset.generate_video(3, "dataset_test", 240)
#
# Cell In[59], line 60, in AcousticWaveDataset.generate_video(self, idx, filename, nb_images)
#      58 def generate_video(self, idx, filename, nb_images):
#      59     u = solve_pde(self.grid, self.nx, self.ndt, self.ddt, self.epicenters[idx], self.velocity_model)
# ...

# %%
# %%HTML
# <video width="640" controls>
#   <source src="dataset_test.mp4" type="video/mp4">
# </video>
# Out:
# <video width="640" controls>
#   <source src="dataset_test.mp4" type="video/mp4">
# </video>
